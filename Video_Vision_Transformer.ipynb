# %%
import os
import io
import imageio
import medmnist
import ipywidgets
import numpy as np
import tensorflow as tf  # for data preprocessing only
import keras
from keras import layers, ops

# Setting seed for reproducibility
SEED = 42
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
keras.utils.set_random_seed(SEED)
# Out:
# 2025-10-30 13:31:54.953031: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# DATA
DATASET_NAME = "organmnist3d"
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE
INPUT_SHAPE = (28, 28, 28, 1)
NUM_CLASSES = 11

# OPTIMIZER
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-5

# TRAINING
EPOCHS = 60

# TUBELET EMBEDDING
PATCH_SIZE = (8, 8, 8)
NUM_PATCHES = (INPUT_SHAPE[0] // PATCH_SIZE[0]) ** 2

# ViViT ARCHITECTURE
LAYER_NORM_EPS = 1e-6
PROJECTION_DIM = 128
NUM_HEADS = 8
NUM_LAYERS = 8

# %%
def download_and_prepare_dataset(data_info: dict):
    """Utility function to download the dataset.

    Arguments:
        data_info (dict): Dataset metadata.
    """
    data_path = keras.utils.get_file(origin=data_info["url"], md5_hash=data_info["MD5"])

    with np.load(data_path) as data:
        # Get videos
        train_videos = data["train_images"]
        valid_videos = data["val_images"]
        test_videos = data["test_images"]

        # Get labels
        train_labels = data["train_labels"].flatten()
        valid_labels = data["val_labels"].flatten()
        test_labels = data["test_labels"].flatten()

    return (
        (train_videos, train_labels),
        (valid_videos, valid_labels),
        (test_videos, test_labels),
    )


# Get the metadata of the dataset
info = medmnist.INFO[DATASET_NAME]

# Get the dataset
prepared_dataset = download_and_prepare_dataset(info)
(train_videos, train_labels) = prepared_dataset[0]
(valid_videos, valid_labels) = prepared_dataset[1]
(test_videos, test_labels) = prepared_dataset[2]
# Out:
# Downloading data from https://zenodo.org/records/10519652/files/organmnist3d.npz?download=1
# 32657349/32657349 ━━━━━━━━━━━━━━━━━━━━ 17s 1us/step

# %%
def preprocess(frames: tf.Tensor, label: tf.Tensor):
    """Preprocess the frames tensors and parse the labels."""
    # Preprocess images
    frames = tf.image.convert_image_dtype(
        frames[
            ..., tf.newaxis
        ],  # The new axis is to help for further processing with Conv3D layers
        tf.float32,
    )
    # Parse label
    label = tf.cast(label, tf.float32)
    return frames, label


def prepare_dataloader(
    videos: np.ndarray,
    labels: np.ndarray,
    loader_type: str = "train",
    batch_size: int = BATCH_SIZE,
):
    """Utility function to prepare the dataloader."""
    dataset = tf.data.Dataset.from_tensor_slices((videos, labels))

    if loader_type == "train":
        dataset = dataset.shuffle(BATCH_SIZE * 2)

    dataloader = (
        dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )
    return dataloader


trainloader = prepare_dataloader(train_videos, train_labels, "train")
validloader = prepare_dataloader(valid_videos, valid_labels, "valid")
testloader = prepare_dataloader(test_videos, test_labels, "test")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761827670.035543    9709 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8945 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:08:00.0, compute capability: 7.5

# %%
class TubeletEmbedding(layers.Layer):
    def __init__(self, embed_dim, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.projection = layers.Conv3D(
            filters=embed_dim,
            kernel_size=patch_size,
            strides=patch_size,
            padding="VALID",
        )
        self.flatten = layers.Reshape(target_shape=(-1, embed_dim))

    def call(self, videos):
        projected_patches = self.projection(videos)
        flattened_patches = self.flatten(projected_patches)
        return flattened_patches

# %%
class PositionalEncoder(layers.Layer):
    def __init__(self, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim

    def build(self, input_shape):
        _, num_tokens, _ = input_shape
        self.position_embedding = layers.Embedding(
            input_dim=num_tokens, output_dim=self.embed_dim
        )
        self.positions = ops.arange(0, num_tokens, 1)

    def call(self, encoded_tokens):
        # Encode the positions and add it to the encoded tokens
        encoded_positions = self.position_embedding(self.positions)
        encoded_tokens = encoded_tokens + encoded_positions
        return encoded_tokens

# %%
def create_vivit_classifier(
    tubelet_embedder,
    positional_encoder,
    input_shape=INPUT_SHAPE,
    transformer_layers=NUM_LAYERS,
    num_heads=NUM_HEADS,
    embed_dim=PROJECTION_DIM,
    layer_norm_eps=LAYER_NORM_EPS,
    num_classes=NUM_CLASSES,
):
    # Get the input layer
    inputs = layers.Input(shape=input_shape)
    # Create patches.
    patches = tubelet_embedder(inputs)
    # Encode patches.
    encoded_patches = positional_encoder(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization and MHSA
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim // num_heads, dropout=0.1
        )(x1, x1)

        # Skip connection
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer Normalization and MLP
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = keras.Sequential(
            [
                layers.Dense(units=embed_dim * 4, activation=ops.gelu),
                layers.Dense(units=embed_dim, activation=ops.gelu),
            ]
        )(x3)

        # Skip connection
        encoded_patches = layers.Add()([x3, x2])

    # Layer normalization and Global average pooling.
    representation = layers.LayerNormalization(epsilon=layer_norm_eps)(encoded_patches)
    representation = layers.GlobalAvgPool1D()(representation)

    # Classify outputs.
    outputs = layers.Dense(units=num_classes, activation="softmax")(representation)

    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
def run_experiment():
    # Initialize model
    model = create_vivit_classifier(
        tubelet_embedder=TubeletEmbedding(
            embed_dim=PROJECTION_DIM, patch_size=PATCH_SIZE
        ),
        positional_encoder=PositionalEncoder(embed_dim=PROJECTION_DIM),
    )

    # Compile the model with the optimizer, loss function
    # and the metrics.
    optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    # Train the model.
    _ = model.fit(trainloader, epochs=EPOCHS, validation_data=validloader)

    _, accuracy, top_5_accuracy = model.evaluate(testloader)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return model


model = run_experiment()
# Out:
# Epoch 1/60
# 2025-10-30 13:35:20.122565: I external/local_xla/xla/service/service.cc:163] XLA service 0x7003a000de50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-30 13:35:20.122576: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-10-30 13:35:20.419365: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-30 13:35:22.241594: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 18/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1111 - loss: 2.6043 - top-5-accuracy: 0.5640
# I0000 00:00:1761827726.907047   23248 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 24s 281ms/step - accuracy: 0.1359 - loss: 2.4060 - top-5-accuracy: 0.6097 - val_accuracy: 0.1429 - val_loss: 2.2389 - val_top-5-accuracy: 0.6584
# Epoch 2/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1998 - loss: 2.1264 - top-5-accuracy: 0.7394 - val_accuracy: 0.2919 - val_loss: 1.8352 - val_top-5-accuracy: 0.8012
# Epoch 3/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2503 - loss: 1.9940 - top-5-accuracy: 0.7683 - val_accuracy: 0.3292 - val_loss: 1.7458 - val_top-5-accuracy: 0.8447
# Epoch 4/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3048 - loss: 1.8421 - top-5-accuracy: 0.8280 - val_accuracy: 0.4286 - val_loss: 1.4946 - val_top-5-accuracy: 0.9006
# Epoch 5/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3306 - loss: 1.6888 - top-5-accuracy: 0.8733 - val_accuracy: 0.4907 - val_loss: 1.3121 - val_top-5-accuracy: 0.9193
# Epoch 6/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4222 - loss: 1.4655 - top-5-accuracy: 0.9217 - val_accuracy: 0.5031 - val_loss: 1.1094 - val_top-5-accuracy: 0.9503
# Epoch 7/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4490 - loss: 1.3894 - top-5-accuracy: 0.9351 - val_accuracy: 0.5280 - val_loss: 1.2051 - val_top-5-accuracy: 0.9565
# Epoch 8/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4706 - loss: 1.3017 - top-5-accuracy: 0.9526 - val_accuracy: 0.5466 - val_loss: 1.0933 - val_top-5-accuracy: 0.9689
# Epoch 9/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5015 - loss: 1.2675 - top-5-accuracy: 0.9537 - val_accuracy: 0.5528 - val_loss: 1.1479 - val_top-5-accuracy: 0.9689
# Epoch 10/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5530 - loss: 1.1370 - top-5-accuracy: 0.9547 - val_accuracy: 0.6149 - val_loss: 0.9616 - val_top-5-accuracy: 0.9752
# Epoch 11/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6025 - loss: 1.0874 - top-5-accuracy: 0.9567 - val_accuracy: 0.6149 - val_loss: 0.9807 - val_top-5-accuracy: 0.9752
# Epoch 12/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6303 - loss: 0.9824 - top-5-accuracy: 0.9660 - val_accuracy: 0.7702 - val_loss: 0.6534 - val_top-5-accuracy: 1.0000
# Epoch 13/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6653 - loss: 0.9176 - top-5-accuracy: 0.9773 - val_accuracy: 0.7453 - val_loss: 0.6917 - val_top-5-accuracy: 0.9752
# Epoch 14/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6982 - loss: 0.8018 - top-5-accuracy: 0.9794 - val_accuracy: 0.7888 - val_loss: 0.6620 - val_top-5-accuracy: 0.9876
# Epoch 15/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7405 - loss: 0.7169 - top-5-accuracy: 0.9876 - val_accuracy: 0.7391 - val_loss: 0.6904 - val_top-5-accuracy: 0.9938
# Epoch 16/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7364 - loss: 0.7047 - top-5-accuracy: 0.9907 - val_accuracy: 0.7453 - val_loss: 0.6985 - val_top-5-accuracy: 0.9938
# Epoch 17/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7487 - loss: 0.6840 - top-5-accuracy: 0.9907 - val_accuracy: 0.8447 - val_loss: 0.5325 - val_top-5-accuracy: 0.9876
# Epoch 18/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7611 - loss: 0.6326 - top-5-accuracy: 0.9949 - val_accuracy: 0.7640 - val_loss: 0.6813 - val_top-5-accuracy: 0.9876
# Epoch 19/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8157 - loss: 0.5240 - top-5-accuracy: 0.9959 - val_accuracy: 0.8758 - val_loss: 0.4202 - val_top-5-accuracy: 1.0000
# Epoch 20/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8301 - loss: 0.4750 - top-5-accuracy: 0.9979 - val_accuracy: 0.8571 - val_loss: 0.4762 - val_top-5-accuracy: 0.9876
# Epoch 21/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8465 - loss: 0.4476 - top-5-accuracy: 0.9979 - val_accuracy: 0.8820 - val_loss: 0.4232 - val_top-5-accuracy: 0.9876
# Epoch 22/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8826 - loss: 0.3261 - top-5-accuracy: 0.9979 - val_accuracy: 0.8882 - val_loss: 0.3695 - val_top-5-accuracy: 0.9876
# Epoch 23/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8960 - loss: 0.3072 - top-5-accuracy: 1.0000 - val_accuracy: 0.8944 - val_loss: 0.3701 - val_top-5-accuracy: 0.9876
# Epoch 24/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8836 - loss: 0.3112 - top-5-accuracy: 0.9969 - val_accuracy: 0.9193 - val_loss: 0.3203 - val_top-5-accuracy: 1.0000
# Epoch 25/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8908 - loss: 0.2844 - top-5-accuracy: 0.9990 - val_accuracy: 0.8882 - val_loss: 0.3844 - val_top-5-accuracy: 0.9938
# Epoch 26/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9238 - loss: 0.2463 - top-5-accuracy: 0.9990 - val_accuracy: 0.8447 - val_loss: 0.3799 - val_top-5-accuracy: 0.9876
# Epoch 27/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9022 - loss: 0.2528 - top-5-accuracy: 1.0000 - val_accuracy: 0.9068 - val_loss: 0.3583 - val_top-5-accuracy: 1.0000
# Epoch 28/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9156 - loss: 0.2474 - top-5-accuracy: 0.9969 - val_accuracy: 0.8696 - val_loss: 0.3403 - val_top-5-accuracy: 1.0000
# Epoch 29/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9279 - loss: 0.2159 - top-5-accuracy: 1.0000 - val_accuracy: 0.8944 - val_loss: 0.3167 - val_top-5-accuracy: 1.0000
# Epoch 30/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9403 - loss: 0.1829 - top-5-accuracy: 1.0000 - val_accuracy: 0.8820 - val_loss: 0.4148 - val_top-5-accuracy: 1.0000
# Epoch 31/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9145 - loss: 0.2423 - top-5-accuracy: 0.9990 - val_accuracy: 0.8385 - val_loss: 0.4588 - val_top-5-accuracy: 1.0000
# Epoch 32/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9495 - loss: 0.1510 - top-5-accuracy: 1.0000 - val_accuracy: 0.9193 - val_loss: 0.2456 - val_top-5-accuracy: 1.0000
# Epoch 33/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9598 - loss: 0.1187 - top-5-accuracy: 1.0000 - val_accuracy: 0.9068 - val_loss: 0.3359 - val_top-5-accuracy: 1.0000
# Epoch 34/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9753 - loss: 0.0884 - top-5-accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.3339 - val_top-5-accuracy: 1.0000
# Epoch 35/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9835 - loss: 0.0635 - top-5-accuracy: 1.0000 - val_accuracy: 0.9255 - val_loss: 0.3515 - val_top-5-accuracy: 1.0000
# Epoch 36/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9887 - loss: 0.0578 - top-5-accuracy: 1.0000 - val_accuracy: 0.9193 - val_loss: 0.3591 - val_top-5-accuracy: 0.9938
# Epoch 37/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9887 - loss: 0.0491 - top-5-accuracy: 1.0000 - val_accuracy: 0.9193 - val_loss: 0.3531 - val_top-5-accuracy: 1.0000
# Epoch 38/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9907 - loss: 0.0342 - top-5-accuracy: 1.0000 - val_accuracy: 0.9255 - val_loss: 0.3603 - val_top-5-accuracy: 1.0000
# Epoch 39/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9949 - loss: 0.0275 - top-5-accuracy: 1.0000 - val_accuracy: 0.9317 - val_loss: 0.3549 - val_top-5-accuracy: 1.0000
# Epoch 40/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9949 - loss: 0.0251 - top-5-accuracy: 1.0000 - val_accuracy: 0.9255 - val_loss: 0.3296 - val_top-5-accuracy: 1.0000
# Epoch 41/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9979 - loss: 0.0149 - top-5-accuracy: 1.0000 - val_accuracy: 0.9006 - val_loss: 0.3559 - val_top-5-accuracy: 0.9938
# Epoch 42/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0091 - top-5-accuracy: 1.0000 - val_accuracy: 0.9193 - val_loss: 0.2944 - val_top-5-accuracy: 1.0000
# Epoch 43/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0065 - top-5-accuracy: 1.0000 - val_accuracy: 0.9255 - val_loss: 0.3051 - val_top-5-accuracy: 1.0000
# Epoch 44/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0071 - top-5-accuracy: 1.0000 - val_accuracy: 0.9255 - val_loss: 0.3071 - val_top-5-accuracy: 1.0000
# Epoch 45/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0053 - top-5-accuracy: 1.0000 - val_accuracy: 0.9317 - val_loss: 0.2984 - val_top-5-accuracy: 1.0000
# Epoch 46/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9990 - loss: 0.0086 - top-5-accuracy: 1.0000 - val_accuracy: 0.9193 - val_loss: 0.3151 - val_top-5-accuracy: 1.0000
# Epoch 47/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9835 - loss: 0.0548 - top-5-accuracy: 1.0000 - val_accuracy: 0.9006 - val_loss: 0.3527 - val_top-5-accuracy: 1.0000
# Epoch 48/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9722 - loss: 0.0874 - top-5-accuracy: 1.0000 - val_accuracy: 0.8634 - val_loss: 0.4808 - val_top-5-accuracy: 0.9938
# Epoch 49/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9434 - loss: 0.1598 - top-5-accuracy: 0.9990 - val_accuracy: 0.8571 - val_loss: 0.4448 - val_top-5-accuracy: 1.0000
# Epoch 50/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9588 - loss: 0.1141 - top-5-accuracy: 1.0000 - val_accuracy: 0.8820 - val_loss: 0.5279 - val_top-5-accuracy: 1.0000
# Epoch 51/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9660 - loss: 0.0872 - top-5-accuracy: 1.0000 - val_accuracy: 0.8882 - val_loss: 0.3706 - val_top-5-accuracy: 1.0000
# Epoch 52/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9835 - loss: 0.0515 - top-5-accuracy: 1.0000 - val_accuracy: 0.9193 - val_loss: 0.3365 - val_top-5-accuracy: 0.9938
# Epoch 53/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9969 - loss: 0.0243 - top-5-accuracy: 1.0000 - val_accuracy: 0.9068 - val_loss: 0.4253 - val_top-5-accuracy: 0.9938
# Epoch 54/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9979 - loss: 0.0167 - top-5-accuracy: 1.0000 - val_accuracy: 0.9068 - val_loss: 0.3709 - val_top-5-accuracy: 0.9938
# Epoch 55/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9990 - loss: 0.0079 - top-5-accuracy: 1.0000 - val_accuracy: 0.9379 - val_loss: 0.3215 - val_top-5-accuracy: 0.9938
# Epoch 56/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9969 - loss: 0.0109 - top-5-accuracy: 1.0000 - val_accuracy: 0.9565 - val_loss: 0.2880 - val_top-5-accuracy: 0.9938
# Epoch 57/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0039 - top-5-accuracy: 1.0000 - val_accuracy: 0.9317 - val_loss: 0.3277 - val_top-5-accuracy: 0.9938
# Epoch 58/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0026 - top-5-accuracy: 1.0000 - val_accuracy: 0.9379 - val_loss: 0.3173 - val_top-5-accuracy: 0.9938
# Epoch 59/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0020 - top-5-accuracy: 1.0000 - val_accuracy: 0.9317 - val_loss: 0.3127 - val_top-5-accuracy: 0.9938
# Epoch 60/60
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0015 - top-5-accuracy: 1.0000 - val_accuracy: 0.9379 - val_loss: 0.3116 - val_top-5-accuracy: 0.9938
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7852 - loss: 1.0467 - top-5-accuracy: 0.9770
# Test accuracy: 78.52%
# Test top 5 accuracy: 97.7%

# %%
NUM_SAMPLES_VIZ = 25
testsamples, labels = next(iter(testloader))
testsamples, labels = testsamples[:NUM_SAMPLES_VIZ], labels[:NUM_SAMPLES_VIZ]

ground_truths = []
preds = []
videos = []

for i, (testsample, label) in enumerate(zip(testsamples, labels)):
    # Generate gif
    testsample = np.reshape(testsample.numpy(), (-1, 28, 28))
    with io.BytesIO() as gif:
        imageio.mimsave(gif, (testsample * 255).astype("uint8"), "GIF", fps=5)
        videos.append(gif.getvalue())

    # Get model prediction
    output = model.predict(ops.expand_dims(testsample, axis=0))[0]
    pred = np.argmax(output, axis=0)

    ground_truths.append(label.numpy().astype("int"))
    preds.append(pred)


def make_box_for_grid(image_widget, fit):
    """Make a VBox to hold caption/image for demonstrating option_fit values.

    Source: https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20Styling.html
    """
    # Make the caption
    if fit is not None:
        fit_str = "'{}'".format(fit)
    else:
        fit_str = str(fit)

    h = ipywidgets.HTML(value="" + str(fit_str) + "")

    # Make the green box with the image widget inside it
    boxb = ipywidgets.widgets.Box()
    boxb.children = [image_widget]

    # Compose into a vertical box
    vb = ipywidgets.widgets.VBox()
    vb.layout.align_items = "center"
    vb.children = [h, boxb]
    return vb


boxes = []
for i in range(NUM_SAMPLES_VIZ):
    ib = ipywidgets.widgets.Image(value=videos[i], width=100, height=100)
    true_class = info["label"][str(ground_truths[i])]
    pred_class = info["label"][str(preds[i])]
    caption = f"T: {true_class} | P: {pred_class}"

    boxes.append(make_box_for_grid(ib, caption))

ipywidgets.widgets.GridBox(
    boxes, layout=ipywidgets.widgets.Layout(grid_template_columns="repeat(5, 200px)")
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GridBox(children=(VBox(children=(HTML(value="'T: pancreas | P: pancreas'"), Box(children=(Image(value=b'GIF89a…
